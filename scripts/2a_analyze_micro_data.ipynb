# %%
import pandas as pd

from da_libraries.manage_data_for_da import StrainDataManager

# %matplotlib qt

# %%
help(StrainDataManager)
# Out:
# Help on class StrainDataManager in module kubota_libraries.manage_data_for_da:
#
# class StrainDataManager(scripts.kubota_libraries.arrange_data.DataOrganizer)
#  |  ひずみデータの個別参照、統計解析を行うクラス
#  |
#  |  Method resolution order:
#  |      StrainDataManager
#  |      scripts.kubota_libraries.arrange_data.DataOrganizer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      コンストラクタ
#  |
#  |  change_data(self)
#  |      同じフォルダー（風向・風速が同じデータ群）の中でデータを変更する関数
#  |      Returns:
#  |          None
#  |
#  |  choose_data(self)
#  |      フォルダー（風向・風速が同じデータ群）およびデータを選択する関数
#  |      Returns:
#  |          None
#  |
#  |  compute_average(self, should_normalize: bool)
#  |      各データフレームの平均値を計算し、それらを連結した新しいデータフレームを作成します。
#  |
#  |      Returns:
#  |          pd.DataFrame: 平均値を含む新しいデータフレーム
#  |
#  |  compute_pca(self, n_components: int)
#  |      PCAを実行
#  |
#  |      Aggs:
#  |          n_components: 何次元にするか
#  |
#  |      Returns:
#  |          pd.DataFrame: PCAをした新しい値
#  |
#  |  display_assemble_average_plot(self, en_y_lim=(), sn_y_lim=())
#  |
#  |  plot_data(self, title: str = None, figure_size: tuple = (20, 15), linewidth=1, tick_font_size: int = 10, label_font_size: int = 40, title_fontsize=50, y_lim=None, font_name='Times New Roman', folder_name: str = 'front_horizontal_1.5mps_with_flapping') -> <function figure at 0x0000020189B00430>
#  |      保持しているデータをプロットする関数．
#  |      Args:
#  |          title: タイトル（デフォルトはNone）
#  |          figure_size: フィギュアサイズ（デフォルトは(20, 15)）
#  |          linewidth: 線の太さ（デフォルトは1）
#  |          tick_font_size: ティックフォントサイズ（デフォルトは10）
#  |          label_font_size: ラベルフォントサイズ（デフォルトは40）
#  |          title_fontsize: タイトルフォントサイズ（デフォルトは50）
#  |          y_lim: Y軸の範囲（デフォルトはNone）
#  |          font_name: フォント名（デフォルトは"Times New Roman"）
#  |          folder_name: フォルダ名（デフォルトは"front_horizontal_1.5mps_with_flapping"）
#  |      Returns:
#  |          plt.figure: 描画したmatplotlibのfigureオブジェクト
#  |
#  |  show_data(self) -> pandas.core.frame.DataFrame
#  |      現在選択されているデータを表示する関数
#  |      Returns:
#  |          pandas.DataFrame: 現在選択されているデータ
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  plot_combinations_2d(df, data_columns, nrows=2, ncols=4)
#  |      Plot sets of 2D combinations of data columns in separate windows, each containing 8 graphs, colored by category.
#  |
#  |      Args:
#  |      - df: DataFrame containing the data.
#  |      - data_columns: List of columns to plot.
#  |      - nrows: Number of rows in each subplot grid.
#  |      - ncols: Number of columns in each subplot grid.
#  |      Returns:
#  |      - figs: List of matplotlib figure objects.
#  |
#  |  plot_combinations_3d(df, data_columns)
#  |      Plot every combination of data columns in 3D, colored by category.
#  |
#  |      Args:
#  |      - df: DataFrame containing the data.
#  |      - data_columns: List of columns to plot.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from scripts.kubota_libraries.arrange_data.DataOrganizer:
#  |
#  |  calculate_filter_frequency_response(self, should_db: bool = True)
#  |      フィルタの周波数応答を計算し、その結果を返す関数。
#  |      Args:
#  |          should_db: デシベルに変換するかどうか
#  |      Returns:
#  |          w: 周波数レスポンス
#  |          amp_dB: デシベル変換された振幅（should_db=Trueの場合）
#  |
#  |  update_filter_parameters(self, m, frequency_c) -> None
#  |      平滑化のパラメータmとfrequency_cを更新し、フィルター係数を再計算する関数。
#  |      Args:
#  |          m: 平滑化のパラメータm (int)
#  |          frequency_c: 平滑化のパラメータfrequency_c (int)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from scripts.kubota_libraries.arrange_data.DataOrganizer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
strain_data_manager = StrainDataManager()
# Out:
# Whole or Split:  Split
# Flatten or Raw:  Raw
# data_split_by_1_periodを選択
# NORMALIZED:  NO
# ['../data/240104_w_shaft/2_split_data\\raw_data\\data_split_by_1_period\\not_normalized\\organized_data.pkl']
#   0%|          | 0/1 [00:00<?, ?it/s]
# After checking the graph of raw data (arranged_strain_dataframes), implement get_split_strain_data_dfs.

# %% [markdown]
# ## 個別データの参照

# %%
strain_data_manager.choose_data()
# Out:
# Folder name: 60deg
# # data: 4

# %%
strain_data_manager.change_data()
# Out:
# # data: 400

# %%
strain_data_manager.show_data()
# strain_data_manager.show_data().to_csv(r"C:\Users\tokyo\PycharmProjects\WindDitection\whole.csv")
# Out:
#         WE   SP        SG1         SG2        SG3        SG4        SG5  \
# 0    60deg  400  -8.664314  117.149857  -6.371000  -8.471143 -76.392570
# 1    60deg  400 -24.585743  103.228432  -5.399571  -0.599714 -84.271141
# 2    60deg  400 -37.714314   77.271286  11.236143   7.328857 -84.963997
# 3    60deg  400 -28.157171   52.228428 -12.499572   3.878857 -75.199715
# 4    60deg  400  -8.678600   29.049858 -40.613857   0.678857 -68.613998
# ..     ...  ...        ...         ...        ...        ...        ...
# 828  60deg  400 -20.192886   76.085571   0.771857  -6.364000 -53.149715
# 829  60deg  400 -11.250029   48.242714 -15.763857   2.978857 -46.549713
# 830  60deg  400   3.642828   15.564143 -25.828142  10.828857 -54.063999
# 831  60deg  400  17.264257   -8.535857 -33.406715  18.193142 -72.071144
# 832  60deg  400  24.814257  -22.635857 -21.985285  13.364572 -85.821144
#
#             SG6        SG7       EN1
# 0    -40.114716 -76.478859  1.285239
# 1    -53.300430 -69.071716  1.288221
# 2    -64.464714 -51.464573  1.293087
# 3    -76.557571 -44.178856  1.299991
# 4    -87.179001 -48.657429  1.302794
# ..          ...        ...       ...
# 828  -74.528999 -50.471714  1.294437
# 829  -78.800430 -36.236000  1.300880
# 830  -82.707573 -31.386000  1.302843
# 831  -91.736145 -40.457428  1.306503
# 832 -101.586143 -55.543144  1.311697
#
# [833 rows x 10 columns]

# %%
s = 30
fig = strain_data_manager.plot_data(title="", label_font_size=s, tick_font_size=s, y_lim=(-1500,1500), figure_size=(40, 30), linewidth=4)

# %%
fig = strain_data_manager.display_assemble_average_plot()
# Out:
# wholeの時のみ実行可能です

# %%
fig.figure.savefig(r"C:\Users\TanakaLaboratory\Downloads\0deg.svg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 fig.figure.savefig(r"C:\Users\TanakaLaboratory\Downloads\0deg.svg")
#
# AttributeError: 'NoneType' object has no attribute 'figure'

# %%
s = 30
fig = strain_data_manager.plot_data(title="", label_font_size=s, tick_font_size=s, y_lim=(-1200,1500), figure_size=(40, 30), linewidth=4)

# %%
fig = strain_data_manager.display_assemble_average_plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 fig = strain_data_manager.display_assemble_average_plot()
#
# File ~\PycharmProjects\WindDitection\scripts\kubota_libraries\manage_data_for_da.py:443, in StrainDataManager.display_assemble_average_plot(self, en_y_lim, sn_y_lim)
#     440     print("Encoder利用時のみ実行可能です")
#     441     return
# --> 443 df = self.show_data().drop(['WE', 'SP'], axis=1)
#     445 # Convert 'EN1' column to categories ranging from 0 to ENCODER_RESOLUTION-1
#     446 df[encoder_column] = pd.cut(df[encoder_column], bins=ENCODER_RESOLUTION, labels=False)
#
# File ~\PycharmProjects\WindDitection\scripts\kubota_libraries\manage_data_for_da.py:276, in StrainDataManager.show_data(self)
#     270 def show_data(self) -> pd.DataFrame:
#     271     """
#     272     現在選択されているデータを表示する関数
#     273     Returns:
#     274         pandas.DataFrame: 現在選択されているデータ
#     275     """
# --> 276     self.__raise_data_not_selected_error()
#     278     if self.whole_or_divided == "whole":
#     279         chosen_strain_data = self.arranged_strain_dataframe.loc[
#     280             self.arranged_strain_dataframe["WE"] == self.selected_wind_environment].copy()
#
# File ~\PycharmProjects\WindDitection\scripts\kubota_libraries\manage_data_for_da.py:205, in StrainDataManager.__raise_data_not_selected_error(self)
#     199 """
#     200 選択されていないデータに対してエラーを発生させる関数
#     201 Returns:
#     202     None（ただし条件が満たされていない場合はValueErrorを発生）
#     203 """
#     204 if self.selected_wind_environment == "":
# --> 205     raise ValueError("choose_data()を実行して、フォルダーを選択してください")
#     207 if self.selected_data_index == -1:
#     208     raise ValueError("change_data()を実行して、データ番号を選択してください")
#
# ValueError: choose_data()を実行して、フォルダーを選択してください

# %%
s = 30
fig = strain_data_manager.plot_data(title="", label_font_size=s, tick_font_size=s, y_lim=(-1200,1500), figure_size=(40, 30), linewidth=4)

# %%
data = strain_data_manager.compute_average(should_normalize=True)
data
# Out:
#            WE   SP       SG1       SG2       SG3       SG4       SG5  \
# 0        0deg    1 -0.599348 -0.790218 -0.536054 -0.208642  0.047897
# 1        0deg    2 -0.561758 -0.767004 -0.550251 -0.416212 -0.048471
# 2        0deg    3 -0.653384 -0.934179 -0.437932 -0.359174 -0.010027
# 3        0deg    4 -0.507683 -0.760744 -0.286035 -0.211879  0.160546
# 4        0deg    5 -0.398598 -0.671239 -0.279848 -0.464392 -0.011645
# ...       ...  ...       ...       ...       ...       ...       ...
# 5275  No Wind  476 -1.299400 -0.492785 -0.251238  1.660347 -0.034849
# 5276  No Wind  477 -0.900065 -0.575323 -0.409553  1.583380  0.072576
# 5277  No Wind  478 -0.650253 -0.413237 -0.397113  1.589537  0.210476
# 5278  No Wind  479 -0.264947  0.177746 -0.076062  1.720807  0.082013
# 5279  No Wind  480 -0.552061 -0.094185 -0.213159  1.544450  0.032269
#
#            SG6       EN1
# 0    -0.607092 -1.208634
# 1     0.154269 -0.607801
# 2    -0.010358 -0.813438
# 3    -4.357914 -0.438592
# 4    -3.611170 -0.345393
# ...        ...       ...
# 5275  0.563002 -0.943447
# 5276  0.557879 -0.940938
# 5277  0.524261 -0.582832
# 5278  0.507032 -0.724079
# 5279  0.454534 -0.968983
#
# [5280 rows x 9 columns]

# %%
data_column_names = ["SG1", "SG2", "SG3", "SG4", "SG5", "SG6", "EN1"]

figs = strain_data_manager.plot_combinations_2d(data, data_column_names)
# Out:
# 5
# 6
# 7

# %%
strain_data_manager.plot_combinations_3d(data, data_column_names)

# %%
data = strain_data_manager.compute_pca(n_components=2)
data
# Out:
# Eigenvalues: [3.5703971 1.3460296]
# Explained Variance Ratio: [0.5099602  0.19225354]
# Cumulative Explained Variance: [0.5099602 0.7022137]
# Loadings in DataFrame:
#            SG1       SG2       SG3       SG4       SG5       SG6       EN1
# PC1 -0.503889 -0.467162 -0.467675 -0.013058 -0.422045  0.163832 -0.322493
# PC2 -0.069570 -0.222286  0.173563 -0.719861  0.052934 -0.605155 -0.168551
#        SP       WE       PC1       PC2
# 0       1     0deg  1.194689  0.848145
# 1       2     0deg  1.145896  0.420214
# 2       3     0deg  1.240010  0.578502
# 3       4     0deg  0.107463  3.026937
# 4       5     0deg  0.176044  2.705580
# ...   ...      ...       ...       ...
# 5275  476  No Wind  1.391982 -1.222415
# 5276  477  No Wind  1.257378 -1.195557
# 5277  478  No Wind  0.870687 -1.283955
# 5278  479  No Wind  0.345535 -1.453469
# 5279  480  No Wind  0.775037 -1.199474
#
# [5280 rows x 4 columns]

# %%
data_column_names = ["PC1", "PC2"]
figs = strain_data_manager.plot_combinations_2d(data, data_column_names, nrows=1, ncols=1)

# %%
data = strain_data_manager.compute_pca(n_components=3)
data
# Out:
# Eigenvalues: [3.5703971 1.3460284 0.8757367]
# Explained Variance Ratio: [0.5099602  0.19225337 0.12508155]
# Cumulative Explained Variance: [0.5099602  0.7022135  0.82729506]
# Loadings in DataFrame:
#            SG1       SG2       SG3       SG4       SG5       SG6       EN1
# PC1 -0.503889 -0.467162 -0.467675 -0.013058 -0.422045  0.163832 -0.322493
# PC2 -0.069569 -0.222286  0.173563 -0.719861  0.052934 -0.605155 -0.168550
# PC3  0.142941  0.090080 -0.322710 -0.294129 -0.483557 -0.040179  0.738484
#        SP       WE       PC1       PC2       PC3
# 0       1     0deg  1.194677  0.848138 -0.813816
# 1       2     0deg  1.145896  0.420215 -0.281017
# 2       3     0deg  1.240010  0.578498 -0.526019
# 3       4     0deg  0.107463  3.026941 -0.212902
# 4       5     0deg  0.176044  2.705583  0.005116
# ...   ...      ...       ...       ...       ...
# 5275  476  No Wind  1.391982 -1.222417 -1.339898
# 5276  477  No Wind  1.257379 -1.195560 -1.266410
# 5277  478  No Wind  0.870688 -1.283958 -1.022803
# 5278  479  No Wind  0.345535 -1.453471 -1.098205
# 5279  480  No Wind  0.775037 -1.199477 -1.222320
#
# [5280 rows x 5 columns]

# %%
data_column_names = ["PC1", "PC2", "PC3"]
fig = strain_data_manager.plot_combinations_3d(data, data_column_names)
